# %%
###Importing CSV file and splitting it into train and test

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\Real-estate.csv')
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
x,y
# Out:
# (      No  X1 transaction date  X2 house age  \
#  0      1             2012.917          32.0
#  1      2             2012.917          19.5
#  2      3             2013.583          13.3
#  3      4             2013.500          13.3
#  4      5             2012.833           5.0
#  ..   ...                  ...           ...
#  409  410             2013.000          13.7
#  410  411             2012.667           5.6
#  411  412             2013.250          18.8
#  412  413             2013.000           8.1
#  413  414             2013.500           6.5
#
#       X3 distance to the nearest MRT station  X4 number of convenience stores  \
#  0                                  84.87882                               10
#  1                                 306.59470                                9
#  2                                 561.98450                                5
#  3                                 561.98450                                5
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x_train,x_test,y_train,y_test
# Out:
# (      No  X1 transaction date  X2 house age  \
#  206  207             2013.250          22.2
#  10    11             2013.083          34.8
#  52    53             2013.583          32.1
#  412  413             2013.000           8.1
#  300  301             2013.083           2.5
#  ..   ...                  ...           ...
#  362  363             2013.417          17.1
#  301  302             2012.750          38.0
#  64    65             2013.333          17.5
#  255  256             2013.417          31.5
#  330  331             2013.083          32.0
#
#       X3 distance to the nearest MRT station  X4 number of convenience stores  \
#  206                                379.5575                               10
#  10                                 405.2134                                1
#  52                                1438.5790                                3
#  412                                104.8101                                5
# ...

# %%
np.shape(x_test)
# Out:
# (104, 7)

# %%
###Importing mat file and splitting it into train and test

# %%
import scipy.io
mat = scipy.io.loadmat(r'C:\Users\Admin\Downloads\mnist.mat')

# %%
mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Tue May 17 12:16:00 2016',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[-3.59999994e-03, -7.38041534e+01,  1.98205963e+02, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         [-3.59999994e-03, -7.38041534e+01,  1.97205963e+02, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         [-3.59999994e-03, -7.38041534e+01, -5.37940331e+01, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         ...,
#         [-3.59999994e-03, -7.38041534e+01, -5.37940331e+01, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         [-3.59999994e-03, -7.38041534e+01, -5.37940331e+01, ...,
#          -6.50000002e-04,  1.25648735e+02,  0.00000000e+00],
#         [-3.59999994e-03, -4.68041534e+01, -5.37940331e+01, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00]]),
#  'y': array([[0],
#         [0],
#         [0],
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(mat['X'],mat['y'])
x_train,x_test,y_train,y_test
# Out:
# (array([[-3.59999994e-03,  4.91958466e+01, -5.37940331e+01, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         [-3.59999994e-03,  1.34195847e+02,  1.98205963e+02, ...,
#          -6.50000002e-04,  2.42648727e+02,  0.00000000e+00],
#         [-3.59999994e-03, -6.78041534e+01,  2.00205963e+02, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         ...,
#         [-3.59999994e-03, -7.38041534e+01,  1.99205963e+02, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         [-3.59999994e-03,  1.76195847e+02, -5.37940331e+01, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         [-3.59999994e-03,  2.11958466e+01,  3.92059669e+01, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00]]),
#  array([[-3.59999994e-03,  1.68195847e+02,  1.02059669e+01, ...,
#          -6.50000002e-04, -1.23512669e+01,  0.00000000e+00],
#         [-3.59999994e-03, -7.38041534e+01,  1.99205963e+02, ...,
# ...

# %%
###Importing xls file and splitting it into train and test

# %%
xls=pd.read_excel(r'C:\Users\Admin\Downloads\insurance.xlsx')

# %%
xls.head()
# Out:
#    Policy     Expiry Location State   Region  InsuredValue Construction  \
# 0  100242 2021-01-02    Urban    NY     East       1617630        Frame
# 1  100314 2021-01-02    Urban    NY     East       8678500  Fire Resist
# 2  100359 2021-01-02    Rural    WI  Midwest       2052660        Frame
# 3  100315 2021-01-03    Urban    NY     East      17580000        Frame
# 4  100385 2021-01-03    Urban    NY     East       1925000      Masonry
#
#   BusinessType Earthquake Flood
# 0       Retail          N     N
# 1    Apartment          Y     Y
# 2      Farming          N     N
# 3    Apartment          Y     Y
# 4  Hospitality          N     N

# %%
x = xls.iloc[:, :-2]
y = xls.iloc[:, -2:]
x,y
# Out:
# (     Policy     Expiry Location State     Region  InsuredValue Construction  \
#  0    100242 2021-01-02    Urban    NY       East       1617630        Frame
#  1    100314 2021-01-02    Urban    NY       East       8678500  Fire Resist
#  2    100359 2021-01-02    Rural    WI    Midwest       2052660        Frame
#  3    100315 2021-01-03    Urban    NY       East      17580000        Frame
#  4    100385 2021-01-03    Urban    NY       East       1925000      Masonry
#  ..      ...        ...      ...   ...        ...           ...          ...
#  495  101121 2021-12-31    Urban    VT  Northeast       4101750  Fire Resist
#  496  101122 2021-12-31    Urban    OH    Central       1739100        Frame
#  497  101123 2021-12-31    Urban    NY       East       2250000        Frame
#  498  101125 2021-12-31    Urban    NY       East      16482200        Frame
#  499  101126 2021-12-31    Urban    WI    Midwest       1776800        Frame
#
#      BusinessType
#  0         Retail
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x_train,x_test,y_train,y_test
# Out:
# (     Policy     Expiry Location State     Region  InsuredValue Construction  \
#  101  100490 2021-03-12    Urban    NY       East        220000   Metal Clad
#  162  100651 2021-05-02    Urban    NJ       East       1045000        Frame
#  232  100746 2021-06-07    Urban    NY       East        847300        Frame
#  459  100204 2021-12-21    Urban    WI    Midwest       1400000      Masonry
#  268  100832 2021-09-10    Urban    NY       East      18275350        Frame
#  ..      ...        ...      ...   ...        ...           ...          ...
#  402  101025 2021-11-28    Urban    WI    Midwest       2502600      Masonry
#  460  100344 2021-12-21    Urban    WI    Midwest       1711268        Frame
#  173  100590 2021-05-08    Rural    WI    Midwest       2798650      Masonry
#  476  100295 2021-12-25    Urban    NJ       East       5114500        Frame
#  426  101053 2021-12-07    Urban    NH  Northeast       1327600        Frame
#
#        BusinessType
#  101    Hospitality
# ...
